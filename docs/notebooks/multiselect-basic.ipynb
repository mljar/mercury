# %%
from mercury import MultiSelect
# Out:
# test

# %%
fruits = MultiSelect(label="Choose fruits", 
               choices=["Apple 🍎", "Banana 🍌", "Cherry 🍒"])

# %%
print(f"You selected: {fruits.value}")
# Out:
# You selected: ['Apple 🍎', 'Cherry 🍒']
