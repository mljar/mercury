# %%
import mercury as mr

# %%
chat = mr.Chat()

# %%
prompt = mr.ChatInput()

# %%
if prompt.value:
    user_msg = mr.Message(prompt.value, role="user")
    chat.add(user_msg)

    response_msg = mr.Message(f"Echo: {prompt.value}", role="assistant", emoji='🤖')
    chat.add(response_msg)
