# %%
import mercury as mr

# %% [markdown]
# # Mercury Input Widgets
#
# In this web app we show case Mercury Input Widgets. They can be used to quickly turn your notebook into interactive web app.

# %% [markdown]
# ### Button

# %%
btn = mr.Button(label="Click me!")

# %%
if btn.value:
    print("You clicked button!")
else:
    print("Button not clicked ...")
# Out:
# Button not clicked ...

# %% [markdown]
# ### Checkbox

# %%
check = mr.CheckBox(label="I agree")

# %%
check2 = mr.CheckBox(label="Consent", appearance="box")

# %%
print(f"Check boxes: {check.value} {check2.value}")
# Out:
# Check boxes: False False

# %% [markdown]
# ### MultiSelect

# %%
fruits = mr.MultiSelect(
    label="Choose fruits",
    choices=["Apple 🍎", "Banana 🍌", "Cherry 🍒"],
    value=["Banana 🍌", "Cherry 🍒"]
)

# %%
print(f"MultiSelect fruits: {fruits.value}")
# Out:
# MultiSelect fruits: ['Apple 🍎']

# %% [markdown]
# ### NumberInput

# %%
rows = mr.NumberInput(
    label="Rows",
    min=10,
    max=100
)

# %%
print(f"Rows: {rows.value}")
# Out:
# Rows: 10.0

# %% [markdown]
# ### Select

# %%
color = mr.Select(
    label="Choose color",
    choices=["Red", "Green", "Blue"]
)

# %%
print(f"Selected color: {color.value}")
# Out:
# Selected color: Red

# %% [markdown]
# ### Slider

# %%
threshold = mr.Slider(
    label="Threshold",
    min=0,
    max=10,
    value=3
)

# %%
print(f"Threshold value: {threshold.value}")
# Out:
# Threshold value: 6

# %% [markdown]
# ### TextInput

# %%
import mercury as mr

name = mr.TextInput(
    label="Enter your name",
    value="Aleksandra"
)

# %%
print(f"Hi {name.value} 👋")
# Out:
# Hi Aleksandra 👋

# %% [markdown]
# ### UploadFile

# %%
import mercury as mr

uploader = mr.UploadFile(
    label="Upload CSV",
    multiple=False
)

# %%
uploader.name
# Out:
# 'version.ipynb'

# %%
if uploader.value:
    print("First characters from file:")
    print(uploader.value[:10])
# Out:
# First characters from file:
# b'{\n "cells"'
