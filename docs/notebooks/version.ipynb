# %%
import mercury

# %% [markdown]
# # Version check

# %%
print("Mercury version", mercury.__version__)
# Out:
# Mercury version 3.0.0a5

# %%
import sys

# %%
# Check Python version
print("Python version", sys.version)
# Out:
# Python version 3.11.10 (main, Sep  1 2025, 10:31:32) [GCC 13.3.0]
