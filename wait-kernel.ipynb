# %%
import mercury as mr
import time

# %%
b1 = mr.Button("10 seconds")
b2 = mr.Button("5 seconds")
b3 = mr.Button("1 seconds")

# %%
if b1.value:
    print("Sleeping 10 seconds")
    time.sleep(10)

if b2.value:
    print("Sleeping 5 seconds")
    time.sleep(5)

if b3.value:
    print("Sleeping 1 second")
    time.sleep(1)

# %%
print('[Done]')
# Out:
# [Done]

# %%
import datetime
print(datetime.datetime.utcnow())
# Out:
# 2025-12-19 13:42:34.366730
